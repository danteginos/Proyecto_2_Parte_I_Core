# %% [markdown]
# Conjunto de datos de clientes de netflix
# * fuente :fuente : UCI Machine Learning Repository
# * Tamaño : 547 kb.
# * entradas : 5000
# * Columnas :
#  * 0   customer_id             5000 non-null   object
#  * 1   age                     5000 non-null   int64
#  * 2   gender                  5000 non-null   object
#  * 3   subscription_type       5000 non-null   object
#  * 4   watch_hours             5000 non-null   float64
#  * 5   last_login_days         5000 non-null   int64
#  * 6   region                  5000 non-null   object
#  * 7   device                  5000 non-null   object
#  * 8   monthly_fee             5000 non-null   float64
#  * 9   churned                 5000 non-null   int64
#  * 10  payment_method          5000 non-null   object
#  * 11  number_of_profiles      5000 non-null   int64
#  * 12  avg_watch_time_per_day  5000 non-null   float64
#  * 13  favorite_genre          5000 non-null   object

# %%
# Se cargan las bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Se usa biblioteca google para poder usar archivos .
from google.colab import drive
# Se conecta colab con drive.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Se carga el conjunto de datos
path ="/content/drive/MyDrive/CLASE MACHINE LEARNING/DATA_CORES/dataset1.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#                             customer_id  age  gender subscription_type  \
# 0  a9b75100-82a8-427a-a208-72f24052884a   51   Other             Basic
# 1  49a5dfd9-7e69-4022-a6ad-0a1b9767fb5b   47   Other          Standard
# 2  4d71f6ce-fca9-4ff7-8afa-197ac24de14b   27  Female          Standard
# 3  d3c72c38-631b-4f9e-8a0e-de103cad1a7d   53   Other           Premium
# 4  4e265c34-103a-4dbb-9553-76c9aa47e946   56   Other          Standard
#
#    watch_hours  last_login_days   region  device  monthly_fee  churned  \
# 0        14.73               29   Africa      TV         8.99        1
# 1         0.70               19   Europe  Mobile        13.99        1
# 2        16.32               10     Asia      TV        13.99        0
# 3         4.51               12  Oceania      TV        17.99        1
# 4         1.89               13   Africa  Mobile        13.99        1
#
#   payment_method  number_of_profiles  avg_watch_time_per_day favorite_genre
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             5000 non-null   object
#  1   age                     5000 non-null   int64
#  2   gender                  5000 non-null   object
#  3   subscription_type       5000 non-null   object
#  4   watch_hours             5000 non-null   float64
#  5   last_login_days         5000 non-null   int64
#  6   region                  5000 non-null   object
#  7   device                  5000 non-null   object
#  8   monthly_fee             5000 non-null   float64
#  9   churned                 5000 non-null   int64
#  10  payment_method          5000 non-null   object
#  11  number_of_profiles      5000 non-null   int64
#  12  avg_watch_time_per_day  5000 non-null   float64
#  13  favorite_genre          5000 non-null   object
# ...

# %% [markdown]
# #### El dataset contiene 5000 entradas con 14 columnas, cada una de ellas esta completa y se tiene 3 float, 1 int y 7 object.

# %%
df.describe().T.round(2)
# Out:
#                          count   mean    std    min    25%    50%    75%  \
# age                     5000.0  43.85  15.50  18.00  30.00  44.00  58.00
# watch_hours             5000.0  11.65  12.01   0.01   3.34   8.00  16.03
# last_login_days         5000.0  30.09  17.54   0.00  15.00  30.00  45.00
# monthly_fee             5000.0  13.68   3.69   8.99   8.99  13.99  17.99
# churned                 5000.0   0.50   0.50   0.00   0.00   1.00   1.00
# number_of_profiles      5000.0   3.02   1.42   1.00   2.00   3.00   4.00
# avg_watch_time_per_day  5000.0   0.87   2.62   0.00   0.11   0.29   0.72
#
#                            max
# age                      70.00
# watch_hours             110.40
# last_login_days          60.00
# monthly_fee              17.99
# churned                   1.00
# number_of_profiles        5.00
# avg_watch_time_per_day   98.42

# %% [markdown]
# * La edad esta en rango de 18 a 70 años, con promedio de 43.85
# * watch_hours en  rango de 0.001 y 110.40, Es un valor alto que llama la atención.
# * last_login_days en rango 0.0 y 60.00
# * monthly_fee  en rango de 8.99 y 17.99.
# * churned      en rango 0.0 y 1.0
# * number_profile 1.00 y 5.00
# * avg_watch_time_per_day en rango 0 a 98. el cual es alto, pero se puede dar el caso que un tv, quede encendido por descuido o niños que los usen.
#
# #### Pueden ser manejados

# %%
df.dtypes
# Out:
# customer_id                object
# age                         int64
# gender                     object
# subscription_type          object
# watch_hours               float64
# last_login_days             int64
# region                     object
# device                     object
# monthly_fee               float64
# churned                     int64
# payment_method             object
# number_of_profiles          int64
# avg_watch_time_per_day    float64
# favorite_genre             object
# dtype: object

# %%
df.isna().sum()
# Out:
# customer_id               0
# age                       0
# gender                    0
# subscription_type         0
# watch_hours               0
# last_login_days           0
# region                    0
# device                    0
# monthly_fee               0
# churned                   0
# payment_method            0
# number_of_profiles        0
# avg_watch_time_per_day    0
# favorite_genre            0
# dtype: int64

# %% [markdown]
# #### No se encuentran datos nulos.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, age, gender, subscription_type, watch_hours, last_login_days, region, device, monthly_fee, churned, payment_method, number_of_profiles, avg_watch_time_per_day, favorite_genre]
# Index: []

# %%
df["gender"].unique()
# Out:
# array(['Other', 'Female', 'Male'], dtype=object)

# %%
df["subscription_type"].unique()
# Out:
# array(['Basic', 'Standard', 'Premium'], dtype=object)

# %% [markdown]
# Se visualizara la variables numericas

# %%
df[["region"]].value_counts()
# Out:
# region
# South America    873
# Europe           867
# North America    851
# Asia             841
# Africa           803
# Oceania          765
# Name: count, dtype: int64

# %%
df["device"].unique()
# Out:
# array(['TV', 'Mobile', 'Laptop', 'Desktop', 'Tablet'], dtype=object)

# %%
df["payment_method"].unique()
# Out:
# array(['Gift Card', 'Crypto', 'Debit Card', 'PayPal', 'Credit Card'],
#       dtype=object)

# %%
df["favorite_genre"].unique()
# Out:
# array(['Action', 'Sci-Fi', 'Drama', 'Horror', 'Romance', 'Comedy',
#        'Documentary'], dtype=object)

# %%
# # Crear la figura y los subplots.
fig, axs = plt.subplots(2,4, figsize=(14, 6))
# Se deja el array en una dimension para no usar indices con dos dimensiones
axs = axs.flatten()
# Columnas numéricas a graficar
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns.to_list()
# Boxplot para las columnas numéricas
prop_caja = dict(facecolor='skyblue')
for i, col in enumerate(numeric_cols[:15]):
  axs[i].boxplot(df[col], patch_artist=True, boxprops=prop_caja)
  axs[i].set_title(f"Boxplot {col}", fontsize=10, fontweight='bold')
  axs[i].set_xticklabels([col], fontweight='bold')
  axs[i].set_ylabel("Valores", fontweight='bold')
  axs[i].grid(True, linewidth=0.5)

# %% [markdown]
# #### Se encuentran datos atipicos en columna avg_watch_time_per_day y en wath_hours. Los cuales estan alejados del resto de los datos. Se puede suponer que son casos reales quwe se dan y dejarlos en el procesamiento o eliminarlos.

# %%
# Se crea el histograma para visualizar los datos atipicos.
plt.hist(df["watch_hours"], bins=10, edgecolor='black')
plt.title('Histograma de Horas Vistas')
plt.xlabel('watch_hours')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# #### La horas vistas se encuentran distribuidas entre 0 y 60 horas, con una gran frecuencia en el rango de 0 a 20 horas

# %%
# Se crea el histograma para visualizar los datos atipicos.
plt.hist(df["avg_watch_time_per_day"], bins=10, edgecolor='black')
plt.title('Histograma Tiempo promedio de visualización por dia ')
plt.xlabel('avg_watch_time_per_day')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# #### El tiempo promedio de visualizaciones por dia se concentra en el rango de 0 a 20 y con una frecuencia muy alta, cerca de 500.
